# %% [markdown]
# <a href="https://colab.research.google.com/github/sijieh/ACNH_project/blob/winnie_branch/ACNH_Music_Genre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
music = pd.read_csv('K.K music info.csv')
villager = pd.read_csv('merged - Villagers.csv')

# %%
music.head()
# Out:
#    Order          Song      Genre                             Instrument  \
# 0      1  K.K. Chorale  Classical                                  Organ
# 1      2    K.K. March      March                 Drums\nCymbals\nHorns
# 2      3    K.K. Waltz      Waltz                             Accordion
# 3      4    K.K. Swing      Swing  Drum kit\nBass\nVibraphone\nWoodwind
# 4      5     K.K. Jazz       Jazz   Drums\nSynthesizer\nElectric guitar
#
#                Mood
# 0  A little blue...
# 1      I feel good!
# 2  A little blue...
# 3         Laid-back
# 4         Laid-back

# %%
music.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107 entries, 0 to 106
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Order       107 non-null    int64
#  1   Song        107 non-null    object
#  2   Genre       101 non-null    object
#  3   Instrument  69 non-null     object
#  4   Mood        107 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 4.3+ KB

# %%
villager.head()
# Out:
#       Name   Species  Gender Personality Subtype    Hobby Birthday  \
# 0      Ace      Bird    Male        Jock       A   Nature   08-Nov
# 1  Admiral      Bird    Male      Cranky       A   Nature   Jan-27
# 2  Agent S  Squirrel  Female       Peppy       B  Fitness   07-Feb
# 3    Agnes       Pig  Female  Big Sister       A     Play   Apr-21
# 4       Al   Gorilla    Male        Lazy       B  Fitness   Oct-18
#
#   Catchphrase  Favorite Song  \
# 0         ace       K.K. Hop
# 1     aye aye     Steep Hill
# 2    sidekick  Go K.K. Rider
# 3     snuffle     K.K. House
# 4     ayyyeee  Go K.K. Rider
#
#                                      Favorite Saying  ...  \
# 0  If you love something, let it go. Then chase i...  ...
# 1                             Only quitters give up.  ...
# 2              You gotta put the pedal to the metal!  ...
# 3                             You reap what you sow.  ...
# 4      Life is a buffet. Always go back for seconds.  ...
#
# ...

# %%
villager.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 413 entries, 0 to 412
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Name                 413 non-null    object
#  1   Species              413 non-null    object
#  2   Gender               413 non-null    object
#  3   Personality          413 non-null    object
#  4   Subtype              413 non-null    object
#  5   Hobby                413 non-null    object
#  6   Birthday             413 non-null    object
#  7   Catchphrase          413 non-null    object
#  8   Favorite Song        413 non-null    object
#  9   Favorite Saying      413 non-null    object
#  10  Style 1              413 non-null    object
#  11  Style 2              413 non-null    object
#  12  Color 1              413 non-null    object
#  13  Color 2              413 non-null    object
#  14  Default Clothing     413 non-null    int64
# ...

# %%
merged_v_m = villager.merge(music, left_on= 'Favorite Song', right_on = 'Song')
villager_music = merged_v_m[['Name', 'Species', 'Gender', 'Personality', 'Hobby', 'Catchphrase', 'Favorite Song', 'Genre', 'Instrument', 'Mood']]

# %%
villager_music.head()
# Out:
#        Name   Species  Gender Personality      Hobby Catchphrase  \
# 0       Ace      Bird    Male        Jock     Nature         ace
# 1   Admiral      Bird    Male      Cranky     Nature     aye aye
# 2  Wart Jr.      Frog    Male      Cranky  Education  grr-ribbit
# 3   Agent S  Squirrel  Female       Peppy    Fitness    sidekick
# 4        Al   Gorilla    Male        Lazy    Fitness     ayyyeee
#
#    Favorite Song                Genre                      Instrument  \
# 0       K.K. Hop              Hip-hop                             NaN
# 1     Steep Hill  Japanese folk rock                              NaN
# 2     Steep Hill  Japanese folk rock                              NaN
# 3  Go K.K. Rider     Television theme  Wurlitzer\nWhistle (acoustic)
# 4  Go K.K. Rider     Television theme  Wurlitzer\nWhistle (acoustic)
#
#                  Mood
# 0    It's hard to say
# 1    A little blue...
# 2    A little blue...
# 3  A little grumpy...
# 4  A little grumpy...
